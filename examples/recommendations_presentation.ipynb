# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)


csv_header = pd.read_csv("./examples/recommendations.csv")
df = pd.DataFrame(csv_header)

df[["Drug", "Source", "Recommendation"]][df["Source"] == "cpic"]
# Out:
#                Drug Source  \
# 1        citalopram   cpic
# 2      atorvastatin   cpic
# 3         ibuprofen   cpic
# 4         celecoxib   cpic
# 5      flurbiprofen   cpic
# 6        lornoxicam   cpic
# 7      escitalopram   cpic
# 9       clopidogrel   cpic
# 13  dexlansoprazole   cpic
# 16      fluvastatin   cpic
# 18        efavirenz   cpic
# 19        meloxicam   cpic
# 20       lovastatin   cpic
# 21       omeprazole   cpic
# 23     lansoprazole   cpic
# 24     pantoprazole   cpic
# 25        piroxicam   cpic
# 27     pitavastatin   cpic
# 28       sertraline   cpic
# 30      pravastatin   cpic
# 31      simvastatin   cpic
# 32       tacrolimus   cpic
# 34        tenoxicam   cpic
# 35     voriconazole   cpic
#
# ...

# %%
df[["Drug", "Source", "Recommendation"]][df["Source"] == "fda"]
# Out:
#                Drug Source  \
# 8      escitalopram    fda
# 10      clopidogrel    fda
# 12          doxepin    fda
# 14  dexlansoprazole    fda
# 22       omeprazole    fda
# 26        piroxicam    fda
# 33       tacrolimus    fda
# 36     voriconazole    fda
# 37        siponimod    fda
# 66         warfarin    fda
# 71     brivaracetam    fda
# 72         clobazam    fda
# 73       dronabinol    fda
# 74     avatrombopag    fda
#
#                                                                                                                                                                                                                                   Recommendation
# 8                                                                                                                                                                                                             May alter systemic concentrations.
# ...

# %%
df
# Out:
#                        Drug Source  \
# 0             amitriptyline   dpwg
# 1                citalopram   cpic
# 2              atorvastatin   cpic
# 3                 ibuprofen   cpic
# 4                 celecoxib   cpic
# 5              flurbiprofen   cpic
# 6                lornoxicam   cpic
# 7              escitalopram   cpic
# 8              escitalopram    fda
# 9               clopidogrel   cpic
# 10              clopidogrel    fda
# 11                  doxepin   dpwg
# 12                  doxepin    fda
# 13          dexlansoprazole   cpic
# 14          dexlansoprazole    fda
# 15              fluvoxamine   dpwg
# 16              fluvastatin   cpic
# 17              fluvastatin   dpwg
# 18                efavirenz   cpic
# 19                meloxicam   cpic
# 20               lovastatin   cpic
# 21               omeprazole   cpic
# 22               omeprazole    fda
# 23             lansoprazole   cpic
# 24             pantoprazole   cpic
# ...
